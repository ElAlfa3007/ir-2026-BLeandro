# %% [markdown]
# # Ejercicio 01: Búsqueda Básica

# %% [markdown]
# Objetivo: En este ejercicio vamos a implementar una búsqueda dentro de un corpus pequeño de textos

# %% [markdown]
# ### Leandro Bravo

# %% [markdown]
# ## _Pasos:_
# 1. Leer el corpus

# %%
import os 

path = "C:\\Users\\leand\\Desktop\\ir2026\\ir26a-main\\data\\gutenberg\\data"
os.listdir(path)

contenidos = {}
for archivo in os.listdir(path):
    with open(os.path.join(path, archivo), "r", encoding="utf-8") as f:
        contenidos[archivo] = f.read()
        print(contenidos[archivo][:10])
# Out:
# The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje
# ﻿The Proje

# %%
import time

start_time = time.time()
query = "Mary"
resultados = []
for key in contenidos.keys():
    if query in contenidos[key]:
        resultados.append(key)

print(f"Los archivos que contienen la palabra '{query}' son: {resultados}")
end_time = time.time()
print(f"Tiempo de búsqueda: {end_time - start_time} segundos")
# Out:
# Los archivos que contienen la palabra 'Mary' son: ['pg100.txt', 'pg11.txt', 'pg1184.txt', 'pg1232.txt', 'pg1260.txt', 'pg1342.txt', 'pg1400.txt', 'pg145.txt', 'pg15399.txt', 'pg161.txt', 'pg16328.txt', 'pg1661.txt', 'pg1952.txt', 'pg20203.txt', 'pg205.txt', 'pg2160.txt', 'pg21839.txt', 'pg23.txt', 'pg2465.txt', 'pg25344.txt', 'pg2554.txt', 'pg2600.txt', 'pg2641.txt', 'pg2701.txt', 'pg28054.txt', 'pg28942.txt', 'pg29090.txt', 'pg3011.txt', 'pg3207.txt', 'pg3268.txt', 'pg3296.txt', 'pg34413.txt', 'pg345.txt', 'pg36034.txt', 'pg37106.txt', 'pg394.txt', 'pg4085.txt', 'pg42538.txt', 'pg42671.txt', 'pg4300.txt', 'pg45.txt', 'pg45368.txt', 'pg47948.txt', 'pg50559.txt', 'pg51252.txt', 'pg5197.txt', 'pg52106.txt', 'pg58031.txt', 'pg59828.txt', 'pg601.txt', 'pg65238.txt', 'pg6761.txt', 'pg67979.txt', 'pg71046.txt', 'pg74.txt', 'pg75201.txt', 'pg76.txt', 'pg768.txt', 'pg829.txt', 'pg831.txt', 'pg84.txt', 'pg844.txt', 'pg8800.txt', 'pg9701.txt']
# Tiempo de búsqueda: 0.05431222915649414 segundos

# %% [markdown]
# 2. Definir una función de búsqueda_

# %%
def buscar(query, contenidos):
    resultados = []
    for key in contenidos.keys():
        if query in contenidos[key]:
            resultados.append(key)
    return resultados

# %% [markdown]
# 3. Separar todo el contenido en palabras

# %%
palabras = set()
for contenido in contenidos.values():
    palabras.update(contenido.split())

print(len(palabras))
# Out:
# 648912

# %% [markdown]
# 4. Usar la función y medir tiempos

# %%
import time

start_time = time.time()
p = "Mary"
for p in palabras:
    buscar(p, contenidos)
end_time = time.time()
print(buscar(p, contenidos))
print(f"Tiempo de búsqueda: {(end_time - start_time)} segundos")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       2
#       3 start_time = time.time()
#       4 p = "Mary"
#       5 for p in palabras:
# ----> 6     buscar(p, contenidos)
#       7 end_time = time.time()
#       8 print(buscar(p, contenidos))
#       9 print(f"Tiempo de búsqueda: {(end_time - start_time)} segundos")
#
# Cell In[9], line 4, in buscar(query, contenidos)
#       1 def buscar(query, contenidos):
#       2     resultados = []
#       3     for key in contenidos.keys():
# ----> 4         if query in contenidos[key]:
#       5             resultados.append(key)
#       6     return resultados
#
# KeyboardInterrupt:

# %%
import time
#Para que no se demore tanto, solo busco una palabra en vez de todas las palabras del vocabulario
start_time = time.time()
query = "Mary"
resultados = buscar(query, contenidos)
end_time = time.time()

print(f"Los archivos que contienen '{query}': {resultados}")
print(f"Tiempo de búsqueda: {end_time - start_time:.4f} segundos")
# Out:
# Los archivos que contienen 'Mary': ['pg100.txt', 'pg11.txt', 'pg1184.txt', 'pg1232.txt', 'pg1260.txt', 'pg1342.txt', 'pg1400.txt', 'pg145.txt', 'pg15399.txt', 'pg161.txt', 'pg16328.txt', 'pg1661.txt', 'pg1952.txt', 'pg20203.txt', 'pg205.txt', 'pg2160.txt', 'pg21839.txt', 'pg23.txt', 'pg2465.txt', 'pg25344.txt', 'pg2554.txt', 'pg2600.txt', 'pg2641.txt', 'pg2701.txt', 'pg28054.txt', 'pg28942.txt', 'pg29090.txt', 'pg3011.txt', 'pg3207.txt', 'pg3268.txt', 'pg3296.txt', 'pg34413.txt', 'pg345.txt', 'pg36034.txt', 'pg37106.txt', 'pg394.txt', 'pg4085.txt', 'pg42538.txt', 'pg42671.txt', 'pg4300.txt', 'pg45.txt', 'pg45368.txt', 'pg47948.txt', 'pg50559.txt', 'pg51252.txt', 'pg5197.txt', 'pg52106.txt', 'pg58031.txt', 'pg59828.txt', 'pg601.txt', 'pg65238.txt', 'pg6761.txt', 'pg67979.txt', 'pg71046.txt', 'pg74.txt', 'pg75201.txt', 'pg76.txt', 'pg768.txt', 'pg829.txt', 'pg831.txt', 'pg84.txt', 'pg844.txt', 'pg8800.txt', 'pg9701.txt']
# Tiempo de búsqueda: 0.0543 segundos
